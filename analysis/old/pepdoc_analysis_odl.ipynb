# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import scipy
import statsmodels.api as s
from sklearn import metrics

import pdb

# %%
sub_list = ['AC_newepoch','AM', 'BB','CM','CR','GG','HA','IB','JM','JR','KK','KT','MC','MH','NF','SB','SG','SOG','TL','ZZ']
data_dir = f'/lab_data/behrmannlab/vlad/pepdoc/results_ex1' #read in the file; first value is the file name
curr_dir = f'/user_data/vayzenbe/GitHub_Repos/pepdoc' #CHANGE AS NEEEDED CAUSE ITS FOR VLAAAD
fig_dir = f'{curr_dir}/figures' #where to save the figures
results_dir = f'{curr_dir}/results' #where to save the results

# bin_size = 1 
categories = ['tool','nontool','bird','insect']
labels = np.asanyarray([0]*5 + [1]*5 + [2]*5 + [3]*5) #creates labels for data



pre_stim = 50 #ms before stim onset
stim_end = 300 #ms when stim goes off
post_stim = 500 #ms after stim offset
bin_length = 4 #length of each bin in ms
bin_size = 1 #how many bins were averaged over; 1 = no averaging; 5 = average over 20 ms

#calculate start window for analysis given the bin size and length
start_window = pre_stim - (bin_length*(bin_size-1)) 
#calculate the onset point of the stimulus in the dataframe given the start window and bin length
stim_onset = int(start_window/bin_length)+1 
stim_offset = int(stim_end/bin_length)+stim_onset-1
timepoints = list(range(-start_window, post_stim, bin_length)) #134 20 ms bins

# %% [markdown]
# #### ERP Plots

# %%
'''
Plot ERPs for each ROI with shading
'''
rois = ['dorsal','ventral']
#rois = ['dorsal']

plt.figure(figsize=(10, 6), dpi=80)
for roi in rois:
    roi_erp = np.load(f'{results_dir}/erp/{roi}_mean_ts.npy')
    if roi == 'control':
        roi_erp = roi_erp *-1
    pre_stim = roi_erp[:,:stim_onset]
    roi_mean = np.mean(roi_erp, axis=0)
    
    sem = np.std(roi_erp, ddof=1, axis =0) / np.sqrt(roi_erp.shape[0])

    plt.plot(timepoints, roi_mean, label=roi) #...plot the data, add error bars to mat plot lib, use standard error of the mean to add., there is a package called psypy to do this (psyplot - SEM)
    plt.axhline(y=0, color='k', linestyle='--')
    
    plt.fill_between(timepoints, roi_mean-sem, roi_mean+sem,alpha=0.5)
    plt.legend()

    plt.xlabel('Time (ms)')
    plt.ylabel('uV')

# %%
'''
Plot ERP  split by hemi
''' 
rois = ['dorsal','ventral']

for roi in rois:
    plt.figure(figsize=(10, 6), dpi=80)
    for lr in ['left','right']:
        roi_erp = np.load(f'{results_dir}/erp/{lr}_{roi}_mean_ts.npy')
        roi_mean = np.mean(roi_erp, axis=0)
        
        sem = np.std(roi_erp, ddof=1, axis =0) / np.sqrt(roi_erp.shape[0])

        plt.plot(timepoints, roi_mean, label=f'{lr} {roi}') #...plot the data, add error bars to mat plot lib, use standard error of the mean to add., there is a package called psypy to do this (psyplot - SEM)
        plt.axhline(y=0.25, color='k', linestyle='--')
        #plt.axhline(y=0.2215, color='k', linestyle='--')
        plt.fill_between(timepoints, roi_mean-sem, roi_mean+sem,alpha=0.5)
        plt.legend()

        plt.xlabel('Time (ms)')
        plt.ylabel('Accuracy (%)')
    plt.show()

# %% [markdown]
# #### Main decoding plots

# %%
"""
Calc bootstrap CIs
"""

# %%
'''
Plot decodeing accuracy for each ROI with shading
'''
rois = ['ventral', 'dorsal']
roi_names = ['Ventral', 'Dorsal']
colors = ['#CC6677','#00949e']

rois = ['dorsal', 'ventral']
colors = ['#00949e','#CC6677']
onsets = [66,82]



plt.figure(figsize=(10, 6), dpi=80)
for roi in enumerate(rois):
    roi_decoding = np.load(f'{results_dir}/decode/{roi[1]}_decoding.npy')
    roi_mean = np.mean(roi_decoding, axis=0)
    
    sem = np.std(roi_decoding, ddof=1, axis =0) / np.sqrt(roi_decoding.shape[0])

    plt.plot(timepoints, roi_mean, label=roi[1].capitalize(), color = colors[roi[0]]) #...plot the data, add error bars to mat plot lib, use standard error of the mean to add., there is a package called psypy to do this (psyplot - SEM)
    plt.axhline(y=0.25, color='k', linestyle='--')
    
    #plt.axhline(y=0.2215, color='k', linestyle='--')
    plt.fill_between(timepoints, roi_mean-sem, roi_mean+sem,alpha=0.5, color = colors[roi[0]])
    plt.legend(fontsize=12)

    plt.xlabel('Time (ms)',fontsize=16)
    plt.ylabel('Accuracy (%)',fontsize=16)
    #plt.axvline(onsets[roi[0]],  linestyle='--', color = colors[roi[0]])
    #plt.yticks(np.arange(min(x), max(x)+1, 1.0))
    plt.xticks(fontsize= 12)
    plt.yticks(fontsize= 12)
    plt.ylim(.2,.4)

    ax = plt.gca()
    ax.xaxis.set_tick_params(width=1.5)
    ax.yaxis.set_tick_params(width=1.5)

    #start, end = ax.get_ylim()
    #ax.yaxis.set_ticks(np.arange(start, end, .05))

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    #plt.show()
    
    plt.savefig(f'{fig_dir}/decoding_plot.png', dpi=300)

# %%
roi_decoding = np.load(f'{results_dir}/decode/dorsal_decoding.npy')
roi_mean = np.mean(roi_decoding, axis=0)
    
np.max(roi_mean)
# Out:
# 0.3484375

# %%
'''
Plot decodeing accuracy for each ROI without shading
'''

rois = ['dorsal','ventral','control']
#rois = ['dorsal']

plt.figure(figsize=(10, 6), dpi=300)
for roi in rois:
    roi_decoding = np.load(f'{results_dir}/{roi}_decoding.npy')
    roi_mean = np.mean(roi_decoding, axis=0)
    
    sem = np.std(roi_decoding, ddof=1, axis =0) / np.sqrt(roi_decoding.shape[0])

    plt.plot(timepoints, roi_mean, label=roi) #...plot the data, add error bars to mat plot lib, use standard error of the mean to add., there is a package called psypy to do this (psyplot - SEM)
    plt.axhline(y=0.25, color='k', linestyle='--')
    #plt.axhline(y=0.2215, color='k', linestyle='--')
    
    plt.legend()

    plt.xlabel('Time (ms)')
    plt.ylabel('Accuracy (%)')

# %%
'''
Plot decoding accuracy split by hemi
''' 
rois = ['dorsal','ventral']

for roi in rois:
    plt.figure(figsize=(10, 6), dpi=80)
    for lr in ['left','right']:
        roi_decoding = np.load(f'{results_dir}/decode/{lr}_{roi}_decoding.npy')
        roi_mean = np.mean(roi_decoding, axis=0)
        
        sem = np.std(roi_decoding, ddof=1, axis =0) / np.sqrt(roi_decoding.shape[0])

        plt.plot(timepoints, roi_mean, label=f'{lr} {roi}') #...plot the data, add error bars to mat plot lib, use standard error of the mean to add., there is a package called psypy to do this (psyplot - SEM)
        plt.axhline(y=0.25, color='k', linestyle='--')
        #plt.axhline(y=0.2215, color='k', linestyle='--')
        plt.fill_between(timepoints, roi_mean-sem, roi_mean+sem,alpha=0.5)
        plt.legend()

        plt.xlabel('Time (ms)')
        plt.ylabel('Accuracy (%)')
    plt.show()

# %% [markdown]
# #### Significance across time

# %%
#dorsal
rois = ['dorsal','ventral']
for roi in rois:
    decoding_data = np.load(f'{results_dir}/decode/{roi}_decoding.npy')
    sig_ts = []
    for time in range(0, decoding_data.shape[1]):
        p_val = stats.ttest_1samp((decoding_data[:,time]), .25, axis = 0, alternative='greater')
        sig_ts.append(p_val[1])

    np.save(f'{results_dir}/decode/{roi}_sig_ts.npy', sig_ts)

# %%
'''
Plot significance time series
'''

rois = ['dorsal','ventral']
line_color = ['#00949e','#CC6677']
alpha_level = .95
plt.figure(figsize=(10, 6), dpi=80)
plt.axhline(alpha_level, color = 'k', label='significance', linestyle='--')
for roi in enumerate(rois):
    sig_data = 1-np.load(f'{results_dir}/decode/{roi[1]}_sig_ts.npy')
    onset = np.min(np.where(sig_data >= alpha_level))
    onset = (onset *bin_length)-start_window
    plt.plot(timepoints, sig_data, label = roi[1], color = line_color[roi[0]])
    plt.axvline(onset,  linestyle='--', color = line_color[roi[0]])
    plt.legend()
    print(roi, onset)
# Out:
# (0, 'dorsal') 66
# (1, 'ventral') 82

# %% [markdown]
# #### Test significant onset

# %%
'''
Calculate onsets for each subject
''' 
alpha_level = .95
rois = ['dorsal','ventral','control']
sub_df = pd.DataFrame()
for roi in rois:
    decoding_sig = np.load(f'{results_dir}/decode/{roi}_decoding_sig.npy')
    decoding_sig = decoding_sig[:,stim_onset:]
    roi_onset = []
    for sub in range(0, decoding_sig.shape[0]):
        sig_times = np.where(decoding_sig[sub,:] <= 1-alpha_level)[0]

        for st in range(0, len(sig_times)):
            if st >0:
                if sig_times[st] - sig_times[st-1] == 1:
                    onset = sig_times[st-1]
                    break

        onset = (onset *bin_length)+4
        roi_onset.append(onset) 
    
    sub_df[roi] = roi_onset
    sub_df.to_csv(f'{results_dir}/onsets/{roi}_sub_onsets.csv')

# %%
'''
Run binomial test on subjects
'''

comparisons = [['dorsal','ventral'] ]

for roi in comparisons:
    #Calcualte the time  difference for each bootstrap between roi pairs
    diff = sub_df[roi[0]] - sub_df[roi[1]]

    #count the number of times the first roi precedes the other
    time_count = np.sum(diff < 0)

    print(stats.binom_test(time_count,n=len(diff), p= 0.5, alternative='two-sided'))
# Out:
# 0.5034446716308594

# %%
'''
Boot strap participant data and extract onset
'''

rois = ['dorsal','ventral']
iter = 1000

boot_df = pd.DataFrame()
for roi in rois:
    decoding_data = np.load(f'{results_dir}/decode/{roi}_decoding.npy')
    decoding_data = decoding_data[:,stim_onset:]
    decoding_data = pd.DataFrame(decoding_data) #convert to dataframe because it has a good resampling function
    decode_boot = []
    sub_counts = np.zeros((1,decoding_data.shape[1]))

    for ii in range(0,iter):
        
        #resample the sub decode data with replacement
        sub_sample = decoding_data.sample(decoding_data.shape[0],replace = True, random_state=ii)
        
        #convert it back to a numpy array
        sub_sample = sub_sample.to_numpy() 
        
        #calculate the bootstrap sample mean
        sig_boot = []
        
        #only add values if they are significant two timepoints in arow
        sig_consistent = []
        
        sig_ts = []
        for time in range(0,sub_sample.shape[1]):
            p_val= stats.ttest_1samp(sub_sample[:,time], .25, axis = 0, alternative='greater')
            
            #append the p-value for every time point
            sig_ts.append(p_val[1])  


            #mark timepoints that are above chance for at least two timepoints in a row
            if time > 0:

                if sig_ts[time] <= .05 and sig_ts[time-1] <=.05:
                    sig_consistent.append(1)
                else:
                    sig_consistent.append(0)

        #reconvert p-value list into a numpy array
        sig_ts = np.asanyarray(sig_ts)

        #reconvert consistent list into a numpy array
        sig_consistent = np.asanyarray(sig_consistent)
            
        #find the the first time point that is below change (0.05)
        #np.where simply returns the indices (i.e., spots in an array), that meet some condition
        #i'm simply grabbing the first value of that list, which corresponds to the first time point above chance
        try:
            sig_onset = np.where(sig_consistent ==1,)[0][0]
        except:
            sig_onset= decoding_data.shape[1]
        
        
        
        sub_counts[0,np.where(sig_ts <=.05)[0]] += 1
        
        #if d_onset == 1:
        #    pdb.set_trace()
        
        #convert to the actual time point
        sig_onset = (sig_onset *4)

        #add the onset value from the resample to a list
        decode_boot.append(sig_onset)
    
    boot_df[roi] = decode_boot

boot_df.to_csv(f'{results_dir}/onsets/onset_boot_df.csv')

# %%
'''
Run binomial test on bootstrapped data
'''

comparisons = [['dorsal','ventral'] ]

for roi in comparisons:
    #Calcualte the time  difference for each bootstrap between roi pairs
    diff = boot_df[roi[0]] - boot_df[roi[1]]

    #count the number of times the first roi precedes the other
    time_count = np.sum(diff < 0)

    print(stats.binom_test(time_count,n=len(diff), p= 0.5, alternative='two-sided'))
    print(time_count)
# Out:
# 5.249291116750507e-27
# 669

# %%
669/1000
# Out:
# 0.669

# %%
colors = ['#00949e','#CC6677']
plt.figure(figsize=(10, 6), dpi=80)
plt.hist(boot_df['dorsal'], range = [0, 300], label='Dorsal', color=colors[0], alpha=.5, bins= 74, density=True)
plt.hist(boot_df['ventral'],range = [0, 300], label='Ventral', color=colors[1], alpha=.5, bins= 74, density=True)
#plt.hist(c_boot,range = [0, 150], label='control', color='g', alpha=.5, bins= 150, density=True)


plt.ylabel('Proportion')
plt.legend(loc='upper right')

plt.legend(fontsize=12)

plt.xlabel('Time (ms)',fontsize=16)
plt.ylabel('Proportion',fontsize=16)
#plt.axvline(onsets[roi[0]],  linestyle='--', color = colors[roi[0]])
#plt.yticks(np.arange(min(x), max(x)+1, 1.0))
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)


ax = plt.gca()
ax.xaxis.set_tick_params(width=1.5)
ax.yaxis.set_tick_params(width=1.5)

#start, end = ax.get_ylim()
#ax.yaxis.set_ticks(np.arange(start, end, .05))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.savefig(f'{fig_dir}/onset_histogram.png', dpi=300)

# %%
np.mean(diff)
# Out:
# -15.952

# %%
#plot the difference values with confidence intervals
alpha = .05
ci_low = np.percentile(diff, alpha*100)
ci_high= np.percentile(diff, 100-alpha*100)
print(ci_low,ci_high)
# Out:
# -68.0 56.0

# %%
plt.boxplot(diff,notch=True)
plt.axhline(0, color = 'k', label='significant', linestyle='--')

# %% [markdown]
# #### Calculate summary stats

# %%
'''
AUC for each subject
'''

rois = ['dorsal','ventral','control', 'left_dorsal', 'right_dorsal', 'left_ventral', 'right_ventral']

sub_df = pd.DataFrame()
for roi in rois:
    decoding_data = np.load(f'{results_dir}/{roi}_decoding.npy')
    decoding_data = decoding_data[:,stim_onset:]
    roi_data=[]
    for sub_n in range(0, decoding_data.shape[0]):
        
        roi_data.append(metrics.auc(np.arange(0,decoding_data.shape[1]), decoding_data[sub_n,:]))

    sub_df[roi] = roi_data

# %%
sns.boxplot(data=sub_df[['dorsal','ventral','control']], notch= True)
plt.xlabel('ROI')
plt.ylabel('AUC')
# Out:
# Text(0, 0.5, 'AUC')

# %% [markdown]
# #### Granger causality

# %%
roi_data1 = np.load(f'{results_dir}/decode/dorsal_decoding.npy')
roi_data1.shape
# Out:
# (20, 138)

# %%
'''
Univariate GCA on decoding
'''

import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests

max_lag = 4

comparisons = [['dorsal','ventral']]
for roi in comparisons:
    roi_fs = []
    
    roi_data1 = np.load(f'{results_dir}/decode/{roi[0]}_decoding.npy')
    roi_data2 = np.load(f'{results_dir}/decode/{roi[1]}_decoding.npy')

    roi_data1 = roi_data1[:,stim_onset:stim_offset]
    roi_data2 = roi_data2[:,stim_onset:stim_offset]
    for sub in range(0,len(sub_list)):
        roi_df = pd.DataFrame()


        roi_df[roi[0]] = roi_data1[sub,:]
        roi_df[roi[1]] =  roi_data2[sub,:]

        roi_df = roi_df.apply(stats.zscore)


        #df = df.diff().dropna()

        gc_1 = grangercausalitytests(roi_df[[roi[0],roi[1]]], maxlag=[max_lag])
        gc_2 = grangercausalitytests(roi_df[[roi[1],roi[0]]], maxlag=[max_lag])

        '''
        roi1_f = []
        roi2_f = []
        for gcn in range(1,len(gc_1)):
            roi1_f.append(gc_1[gcn][0]['ssr_ftest'][0])
            roi2_f.append(gc_2[gcn][0]['ssr_ftest'][0])

        max_roi_1 = np.max(roi1_f)
        max_roi_2 = np.max(roi2_f)
        '''
        roi1_f = gc_1[max_lag][0]['ssr_ftest'][0]
        roi2_f = gc_2[max_lag][0]['ssr_ftest'][0]

        roi_fs.append(roi1_f - roi2_f)
# Out:
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4437  , p=0.2305  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=6.6267  , p=0.1570  , df=4
# likelihood ratio test: chi2=6.3315  , p=0.1757  , df=4
# parameter F test:         F=1.4437  , p=0.2305  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2513  , p=0.9078  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=1.1535  , p=0.8857  , df=4
# likelihood ratio test: chi2=1.1441  , p=0.8872  , df=4
# parameter F test:         F=0.2513  , p=0.9078  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4961  , p=0.7386  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=2.2771  , p=0.6849  , df=4
# likelihood ratio test: chi2=2.2409  , p=0.6916  , df=4
# parameter F test:         F=0.4961  , p=0.7386  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5195  , p=0.7217  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=2.3845  , p=0.6654  , df=4
# likelihood ratio test: chi2=2.3448  , p=0.6726  , df=4
# parameter F test:         F=0.5195  , p=0.7217  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0234  , p=0.9989  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=0.1075  , p=0.9986  , df=4
# likelihood ratio test: chi2=0.1074  , p=0.9986  , df=4
# parameter F test:         F=0.0234  , p=0.9989  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.5724  , p=0.0027  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=20.9881 , p=0.0003  , df=4
# likelihood ratio test: chi2=18.3564 , p=0.0011  , df=4
# parameter F test:         F=4.5724  , p=0.0027  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3362  , p=0.2668  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=6.1333  , p=0.1894  , df=4
# likelihood ratio test: chi2=5.8794  , p=0.2083  , df=4
# parameter F test:         F=1.3362  , p=0.2668  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7544  , p=0.5590  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=3.4627  , p=0.4836  , df=4
# likelihood ratio test: chi2=3.3798  , p=0.4964  , df=4
# parameter F test:         F=0.7544  , p=0.5590  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.0306  , p=0.1013  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=9.3209  , p=0.0536  , df=4
# likelihood ratio test: chi2=8.7504  , p=0.0676  , df=4
# parameter F test:         F=2.0306  , p=0.1013  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9097  , p=0.1202  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=8.7660  , p=0.0672  , df=4
# likelihood ratio test: chi2=8.2591  , p=0.0825  , df=4
# parameter F test:         F=1.9097  , p=0.1202  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.7309  , p=0.1548  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=7.9453  , p=0.0936  , df=4
# likelihood ratio test: chi2=7.5258  , p=0.1106  , df=4
# parameter F test:         F=1.7309  , p=0.1548  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0072  , p=0.4108  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=4.6232  , p=0.3282  , df=4
# likelihood ratio test: chi2=4.4769  , p=0.3453  , df=4
# parameter F test:         F=1.0072  , p=0.4108  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.8187  , p=0.0326  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=12.9381 , p=0.0116  , df=4
# likelihood ratio test: chi2=11.8719 , p=0.0183  , df=4
# parameter F test:         F=2.8187  , p=0.0326  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7040  , p=0.5923  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=3.2314  , p=0.5199  , df=4
# likelihood ratio test: chi2=3.1590  , p=0.5316  , df=4
# parameter F test:         F=0.7040  , p=0.5923  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8965  , p=0.4717  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=4.1153  , p=0.3906  , df=4
# likelihood ratio test: chi2=3.9988  , p=0.4062  , df=4
# parameter F test:         F=0.8965  , p=0.4717  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.9942  , p=0.0253  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=13.7440 , p=0.0082  , df=4
# likelihood ratio test: chi2=12.5488 , p=0.0137  , df=4
# parameter F test:         F=2.9942  , p=0.0253  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.5816  , p=0.0027  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=21.0303 , p=0.0003  , df=4
# likelihood ratio test: chi2=18.3888 , p=0.0010  , df=4
# parameter F test:         F=4.5816  , p=0.0027  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6234  , p=0.6476  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=2.8615  , p=0.5813  , df=4
# likelihood ratio test: chi2=2.8046  , p=0.5910  , df=4
# parameter F test:         F=0.6234  , p=0.6476  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6789  , p=0.6092  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=3.1162  , p=0.5386  , df=4
# likelihood ratio test: chi2=3.0489  , p=0.5497  , df=4
# parameter F test:         F=0.6789  , p=0.6092  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5482  , p=0.7010  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=2.5165  , p=0.6417  , df=4
# likelihood ratio test: chi2=2.4723  , p=0.6496  , df=4
# parameter F test:         F=0.5482  , p=0.7010  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4853  , p=0.7464  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=2.2276  , p=0.6940  , df=4
# likelihood ratio test: chi2=2.1929  , p=0.7003  , df=4
# parameter F test:         F=0.4853  , p=0.7464  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6902  , p=0.6015  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=3.1682  , p=0.5301  , df=4
# likelihood ratio test: chi2=3.0986  , p=0.5415  , df=4
# parameter F test:         F=0.6902  , p=0.6015  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2139  , p=0.0779  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=10.1620 , p=0.0378  , df=4
# likelihood ratio test: chi2=9.4888  , p=0.0500  , df=4
# parameter F test:         F=2.2139  , p=0.0779  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.7033  , p=0.0385  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=12.4087 , p=0.0146  , df=4
# likelihood ratio test: chi2=11.4237 , p=0.0222  , df=4
# parameter F test:         F=2.7033  , p=0.0385  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1144  , p=0.0898  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=9.7056  , p=0.0457  , df=4
# likelihood ratio test: chi2=9.0891  , p=0.0589  , df=4
# parameter F test:         F=2.1144  , p=0.0898  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2062  , p=0.9340  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=0.9466  , p=0.9178  , df=4
# likelihood ratio test: chi2=0.9403  , p=0.9187  , df=4
# parameter F test:         F=0.2062  , p=0.9340  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5996  , p=0.1859  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=7.3426  , p=0.1189  , df=4
# likelihood ratio test: chi2=6.9825  , p=0.1368  , df=4
# parameter F test:         F=1.5996  , p=0.1859  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2648  , p=0.0724  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=10.3956 , p=0.0343  , df=4
# likelihood ratio test: chi2=9.6925  , p=0.0459  , df=4
# parameter F test:         F=2.2648  , p=0.0724  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9505  , p=0.4412  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=4.3628  , p=0.3591  , df=4
# likelihood ratio test: chi2=4.2322  , p=0.3755  , df=4
# parameter F test:         F=0.9505  , p=0.4412  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8062  , p=0.5260  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=3.7008  , p=0.4480  , df=4
# likelihood ratio test: chi2=3.6063  , p=0.4619  , df=4
# parameter F test:         F=0.8062  , p=0.5260  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4865  , p=0.7456  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=2.2330  , p=0.6930  , df=4
# likelihood ratio test: chi2=2.1982  , p=0.6994  , df=4
# parameter F test:         F=0.4865  , p=0.7456  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2596  , p=0.2957  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=5.7816  , p=0.2161  , df=4
# likelihood ratio test: chi2=5.5552  , p=0.2349  , df=4
# parameter F test:         F=1.2596  , p=0.2957  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9716  , p=0.4297  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=4.4597  , p=0.3474  , df=4
# likelihood ratio test: chi2=4.3233  , p=0.3640  , df=4
# parameter F test:         F=0.9716  , p=0.4297  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.5857  , p=0.0109  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=16.4591 , p=0.0025  , df=4
# likelihood ratio test: chi2=14.7824 , p=0.0052  , df=4
# parameter F test:         F=3.5857  , p=0.0109  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6871  , p=0.1646  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=7.7440  , p=0.1014  , df=4
# likelihood ratio test: chi2=7.3448  , p=0.1187  , df=4
# parameter F test:         F=1.6871  , p=0.1646  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5621  , p=0.1958  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=7.1702  , p=0.1272  , df=4
# likelihood ratio test: chi2=6.8262  , p=0.1454  , df=4
# parameter F test:         F=1.5621  , p=0.1958  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3706  , p=0.8287  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=1.7010  , p=0.7905  , df=4
# likelihood ratio test: chi2=1.6806  , p=0.7942  , df=4
# parameter F test:         F=0.3706  , p=0.8287  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.0277  , p=0.0058  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=18.4877 , p=0.0010  , df=4
# likelihood ratio test: chi2=16.4058 , p=0.0025  , df=4
# parameter F test:         F=4.0277  , p=0.0058  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1791  , p=0.9484  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=0.8222  , p=0.9354  , df=4
# likelihood ratio test: chi2=0.8174  , p=0.9361  , df=4
# parameter F test:         F=0.1791  , p=0.9484  , df_denom=61, df_num=4
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5444  , p=0.7037  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=2.4988  , p=0.6449  , df=4
# likelihood ratio test: chi2=2.4552  , p=0.6527  , df=4
# parameter F test:         F=0.5444  , p=0.7037  , df_denom=61, df_num=4

# %% [markdown]
# #### Time generalized RSA analyses

# %%
"""
Plot time generalization RDMs
"""

rois = ['dorsal','ventral']
#rois = ['dorsal']

#timepoints = np.asanyarray(timepoints)
time_cols = np.asanyarray(timepoints)
time_cols[1:] = time_cols[1:] + 2
for roi1 in rois:
    for roi2 in rois:
        corr_ts = np.load(f'{results_dir}/rsa/{roi1}_{roi2}_corr_ts.npy')
        
        corr_df = pd.DataFrame(corr_ts, columns = time_cols, index = time_cols)
        corr_df = corr_df.iloc[stim_onset:stim_offset,stim_onset:stim_offset]
        ax = sns.heatmap(corr_df,xticklabels=12,yticklabels=12, vmin = -1, vmax = 1, cmap= "vlag")
        #ax.set_title(f'{roi1} {roi2}')
        ax.invert_yaxis()
        plt.axvline(13,  linestyle='--', color = 'black')
        plt.axhline(13,  linestyle='--', color = 'black')
        plt.ylabel(roi1)
        plt.xlabel(roi2)
        plt.show()

# %%
"""
Test whether RDMs are right shifted or left shifted
"""
rois = ['dorsal','ventral','control']


#timepoints = np.asanyarray(timepoints)
time_cols = np.asanyarray(timepoints)
time_cols[1:] = time_cols[1:] + 2
df = pd.DataFrame()
for roi1 in rois:
    for roi2 in rois:
        if roi1 == roi2:
            continue
        else:
            corr_ts = np.load(f'{results_dir}/rsa/{roi1}_{roi2}_corr_ts.npy')
            corr_ts = corr_ts[stim_onset:stim_offset,stim_onset:stim_offset]

            #extract left and right sides of the diagnol
            inds = np.triu_indices(n=corr_ts.shape[0],k=1)
            right_side = corr_ts[inds] #extract lower triangle
            left_side = corr_ts[(inds[1],inds[0])] #extract upper triangle

            #calculate the difference between the left and right sides
            #if positive, then right shifted
            diff = right_side - left_side


            df[f'{roi1}_{roi2}'] = diff
            #left side rdm

# %%
(74*73)/2
# Out:
# 2701.0

# %%
sns.barplot(data = df[['dorsal_ventral','dorsal_control','ventral_control']],n_boot=10000,)
plt.axhline(0, color = 'k', label='significant', linestyle='--')
plt.xlabel('ROIs')
plt.ylabel('Time Diff')
# Out:
# Text(0, 0.5, 'Time Diff')

# %%
"""
Test whether RDMs are right shifted or left shifted
"""
rois = ['dorsal','ventral','control']

time_offset = 13
#timepoints = np.asanyarray(timepoints)
time_cols = np.asanyarray(timepoints)
time_cols[1:] = time_cols[1:] + 2
df = pd.DataFrame()
for roi1 in rois:
    for roi2 in rois:
        if roi1 == roi2:
            continue
        else:
            corr_ts = np.load(f'{results_dir}/rsa/{roi1}_{roi2}_corr_ts.npy')
            corr_ts = corr_ts[stim_onset:stim_offset,stim_onset:stim_offset]

            eye_mat = np.eye(corr_ts.shape[0],corr_ts.shape[1], k = 0)
            for t in range(1,time_offset):
                eye_mat = eye_mat+ np.eye(corr_ts.shape[0],corr_ts.shape[1], k = t)
                eye_mat = eye_mat+ np.eye(corr_ts.shape[0],corr_ts.shape[1], k = -t)

            corr_ts =corr_ts*eye_mat

            #extract left and right sides of the diagnol
            inds = np.triu_indices(n=corr_ts.shape[0],k=1)
            diaganol = corr_ts[np.triu_indices(n=corr_ts.shape[0],k=0)] #extract lower triangle
            right_side = corr_ts[inds] #extract lower triangle
            left_side = corr_ts[(inds[1],inds[0])] #extract upper triangle

            #remove zeros
            diaganol = diaganol[diaganol != 0]
            left_side = left_side[left_side != 0]
            right_side = right_side[right_side != 0]

            #calculate the difference between the left and right sides
            #if positive, then right shifted
            diff = right_side - left_side


            df[f'{roi1}_{roi2}'] = diff
    
            #left side rdm

# %%
(np.sum(eye_mat == 1) -74)/2
# Out:
# 621.0

# %%
df.mean()
# Out:
# dorsal_ventral     0.013766
# dorsal_control     0.013087
# ventral_dorsal    -0.013766
# ventral_control   -0.047894
# control_dorsal    -0.013087
# control_ventral    0.047894
# dtype: float64

# %%
sns.barplot(data = df[['dorsal_ventral','dorsal_control','ventral_control']])
plt.axhline(0, color = 'k', label='significant', linestyle='--')
plt.xlabel('ROIs')
plt.ylabel('Time Diff')
# Out:
# Text(0, 0.5, 'Time Diff')

# %%
(74*73)/2
# Out:
# 2701.0

# %%
df.mean()
# Out:
# dorsal_ventral    -0.013959
# dorsal_control    -0.037893
# ventral_dorsal     0.013959
# ventral_control    0.015562
# control_dorsal     0.037893
# control_ventral   -0.015562
# dtype: float64

# %%
(74*73)/2
# Out:
# 2701.0
