# %%
from nilearn import plotting
from nilearn import image
import matplotlib.pyplot as plt
import subprocess
import os
# %matplotlib inline

# %%
#set directories
curr_dir = f'/user_data/vayzenbe/GitHub_Repos/fmri'
anat= f'{curr_dir}/roiParcels/MNI152_T1_2mm_brain.nii.gz'
roi_dir= f'{curr_dir}/roiParcels/mruczek_parcels/binary'
#list out ROIs
rois = ['lPPC','rPPC','ventral_visual_cortex']

# %%
roi = f'{roi_dir}/{rois[2]}.nii.gz'# select ROI
plotting.view_img(roi,bg_img=anat, opacity=.5) #show ROI in interactive figure
# Out:
# /home/vayzenbe/anaconda3/envs/fmri_new/lib/python3.8/site-packages/nilearn/plotting/html_document.py:57: UserWarning: It seems you have created more than 10 nilearn views. As each view uses dozens of megabytes of RAM, you might want to delete some of them.
#   warnings.warn('It seems you have created more than {} '
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
# ...
